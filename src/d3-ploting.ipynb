# %%
from RRTG_helpers import *
import pandas as pd
import numpy as np
import c_graph_lib.bin.tourny as tou
from graph_plot_js import tourny_html_code

# %%
import os
from sage.misc.viewer import browser

for g in digraphs.tournaments_nauty(4):
    os.system('%s %s 2>/dev/null 1>/dev/null &' % (browser(), tourny_html_code(G=g, vertex_labels=False, edge_partition=upsets_not_upsets(g), link_distance=100, vertex_size=4)))
